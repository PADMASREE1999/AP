# %% [markdown]
# <a href="https://colab.research.google.com/github/PADMASREE1999/AP/blob/master/Assignment_(26_06_2020).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##CSE - 221710307059 - Tummala Sai Padmasree

# %% [markdown]
# ###Question 1:
# Write a program to insert a node in doubly linked list.
#
# Test Data: 10 20 40
# Expected Output 10 20 30 40

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>
struct node{
   int data;
   struct node *prev,*next;
}*s,*l,*c,*p;
void insertnode()
{
    struct node *nn;
    nn=(struct Node *)malloc(sizeof(struct node));
    printf("\n Enter a Value : ");
    scanf("%d",&nn->data);
    nn->next=NULL;
    nn->prev=NULL;
    if(s==NULL)
    {
        s=l=nn;
    }
    else
    {
        if(nn->data < s->data)
        {
            nn->next=s;
            s->prev=nn;
            s=nn;
        }
        else if(nn->data > l->data)
        {
            l->next=nn;
            nn->prev=l;
            l=nn;
        }
        else
        {
            for(c=s;c->data < nn->data;p=c,c=c->next);
            nn->next=c;
            nn->prev=p;
            p->next=nn;
            c->prev=nn;
        }
    }
    printf("\n Node is inserted..");
}
void deletenode()
{

}
void display()
{
    //By use of next and by use of prev
    int p;
    if(s==NULL)
    {
        printf("\n Doubly Linked list Empty");

    }
    else
    {
        printf("\n select the order: ");
        printf("\n 1. Forward order ");
        printf("\n 2. Reverse order ");
        scanf("%d",&p);
        switch(p)
        {
            case 1: for(c=s;c!=NULL;c=c->next)
                    {
                        printf("%d ",c->data);
                    }
                    break;
            case 2: for(c=l;c!=NULL;c=c->prev)
                    {
                        printf("%d ",c->data);
                    }
                    break;
        }
    }
}
int main()
{
    int x;
    s=l=c=p=NULL;
    while(1)
    {
        system("cls");
        printf("\n Doubly Linked List");
        printf("\n 1. Insert");
        printf("\n 2. Delete");
        printf("\n 3. Display");
        printf("\n 4. Exit");
        printf("\n Enter your choice : ");
        scanf("%d",&x);
        switch(x)
        {
            case 1:insertnode();
            break;
            case 2:deletenode();
            break;
            case 3:display();
            break;
            case 4:printf("\n Program is terminated");
            return ;
            break;

        }
    }
}

# %% [markdown]
# ###Question 2:
#  Write a program to delete a node in a doubly linked list .
#
# Test Data: 10 20 30
# Expected Output : 10 30

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>
struct node{
   int data;
   struct node *prev,*next;
}*s,*l,*c,*p;
void insertnode()
{
    struct node *nn;
    nn=(struct node *)malloc(sizeof(struct node));
    printf("\n enter a value: ");
    scanf("%d",&nn->data);
    nn->next=NULL;
    nn->next=NULL;
    if(s==NULL)
    {
        s=l=nn;
    }
    else{
        l->next=nn;
        nn->prev=l;
        l=nn;
    }
    printf("\n Node is inserted at the end...");

}
void deletenode(int n)
{
    if(s==NULL)
        return NULL;
    if(s->next==NULL)
    {
        s=NULL;
        return NULL;
    }
    struct node* copyhead = s;
    int mid = n/2;
    while(mid-- > 1)
    {
        s=s->next;
    }
    s->next=s->next->next;

}
void display()
{
    //By use of next and by use of prev
    int p;
    if(s==NULL)
    {
        printf("\n Doubly Linked list Empty");

    }
    else
    {
        printf("\n select the order: ");
        printf("\n 1. Forward order ");
        printf("\n 2. Reverse order ");
        scanf("%d",&p);
        switch(p)
        {
            case 1: for(c=s;c!=NULL;c=c->next)
                    {
                        printf("%d ",c->data);
                    }
                    break;
            case 2: for(c=l;c!=NULL;c=c->prev)
                    {
                        printf("%d ",c->data);
                    }
                    break;
        }
    }
    getch();
}
int main()
{
    int x,count=0;
    s=l=c=p=NULL;
    while(1)
    {
        system("cls");
        printf("\n Doubly Linked List");
        printf("\n 1. Insert");
        printf("\n 2. Delete");
        printf("\n 3. Display");
        printf("\n 4. Exit");
        printf("\n Enter your choice : ");
        scanf("%d",&x);
        switch(x)
        {
            case 1:insertnode();
            count++;
            break;
            case 2:deletenode(count);
            break;
            case 3:display();
            break;
            case 4:printf("\n Program is terminated");
            return ;
            break;

        }
    }
}
